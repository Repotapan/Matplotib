# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(1,10,200)

# %%
x
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518,
#         1.45226131,  1.49748744,  1.54271357,  1.5879397 ,  1.63316583,
#         1.67839196,  1.72361809,  1.76884422,  1.81407035,  1.85929648,
#         1.90452261,  1.94974874,  1.99497487,  2.04020101,  2.08542714,
#         2.13065327,  2.1758794 ,  2.22110553,  2.26633166,  2.31155779,
#         2.35678392,  2.40201005,  2.44723618,  2.49246231,  2.53768844,
#         2.58291457,  2.6281407 ,  2.67336683,  2.71859296,  2.7638191 ,
#         2.80904523,  2.85427136,  2.89949749,  2.94472362,  2.98994975,
#         3.03517588,  3.08040201,  3.12562814,  3.17085427,  3.2160804 ,
#         3.26130653,  3.30653266,  3.35175879,  3.39698492,  3.44221106,
#         3.48743719,  3.53266332,  3.57788945,  3.62311558,  3.66834171,
#         3.71356784,  3.75879397,  3.8040201 ,  3.84924623,  3.89447236,
# ...

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.84147098,  0.86503801,  0.88683599,  0.90682034,  0.92495019,
#         0.94118847,  0.95550197,  0.96786141,  0.97824152,  0.98662108,
#         0.99298295,  0.99731411,  0.99960571,  0.99985306,  0.99805565,
#         0.99421717,  0.98834546,  0.98045253,  0.97055453,  0.95867168,
#         0.9448283 ,  0.9290527 ,  0.91137713,  0.89183774,  0.8704745 ,
#         0.84733109,  0.82245485,  0.79589664,  0.76771077,  0.7379549 ,
#         0.70668987,  0.67397962,  0.63989104,  0.60449386,  0.56786045,
#         0.53006573,  0.491187  ,  0.45130377,  0.4104976 ,  0.36885193,
#         0.32645195,  0.28338435,  0.23973722,  0.19559981,  0.15106239,
#         0.10621603,  0.06115246,  0.01596383, -0.02925744, -0.07441889,
#        -0.11942814, -0.16419316, -0.20862239, -0.25262498, -0.29611093,
#        -0.33899133, -0.38117846, -0.42258607, -0.46312947, -0.50272574,
#        -0.54129391, -0.5787551 , -0.61503271, -0.65005254, -0.68374298,
# ...

# %%
plt.plot(x,y)
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.plot(x,y)
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
plt.show()

# %%
x=np.random.rand(1,10,50)

# %%
y=np.random.rand(1,10,50)

# %%
plt.scatter(x,y)

# %%
colour=np.random.rand(1,10,50)
size=np.random.rand(1,10,50)
plt.scatter(x,y,c=colour,s=200*size,alpha=0.6)#alpha is used to intensiity of colour
plt.xlabel('X_Axis')
plt.ylabel('Y_Axis')
plt.title('My Title')
plt.show()

# %%
x=['a','b','c','d','e']

# %%
y=np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.29347747, 0.85820854, 0.94253214, 0.47703146, 0.47424084])

# %%
plt.bar(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Barplot')
# Out:
# Text(0.5, 1.0, 'Barplot')

# %%
plt.barh(x,y)#barh for horaizental 
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Barplot in horaizental')
# Out:
# Text(0.5, 1.0, 'Barplot in horaizental')

# %%
plt.plot(x,y,'--r')#-- for dash dash line
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.plot(x,y,'--b')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.plot(x,y,'--y')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.figure(figsize=(4,4))
plt.plot(x,y,'--y')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.figure(figsize=(2,6))
plt.plot(x,y,'--y')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
# Out:
# Text(0.5, 1.0, 'This is my title')

# %%
plt.figure(figsize=(4,4))
plt.plot(x,y,'--y')
plt.xlabel('This is my x data')
plt.ylabel('This is my y data')
plt.title('This is my title')
plt.grid()
plt.show()

# %%
x=np.random.rand(1,10,50)
y=np.random.rand(1,10,50)
colour=np.random.rand(1,10,50)
size=np.random.rand(1,10,50)
plt.scatter(x,y,c='#008000',s=100*size,alpha=0.6)#alpha is used to intensiity of colour
plt.xlabel('X_Axis')
plt.ylabel('Y_Axis')
plt.title('My Title')
plt.show()

# %%
x=np.random.rand(1,10,50)
y=np.random.rand(1,10,50)
colour=np.random.rand(1,10,50)
size=np.random.rand(1,10,50)
plt.scatter(x,y,c='#008000',s=100*size,alpha=0.6,marker='*')#alpha is used to intensiity of colour
plt.xlabel('X_Axis')
plt.ylabel('Y_Axis')
plt.title('My Title')
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[6,7,8,9,10,11]

# %%
plt.plot(x,y,c='r',alpha=0.8,marker='*')
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[40,80,70,60,50,90]
plt.plot(x,y,c='r',alpha=0.8,marker='*')
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[40,80,70,60,50,90]
plt.scatter(x,y,c='b',alpha=0.8,marker='*')
plt.show()

# %%
data=[1,2,3,4,1,3,4,5,6,1,2,3,4,5,6,7]

# %%
plt.hist(data)
plt.xlabel('Data Distribution')
plt.ylabel('Frequency of data ')
plt.show()

# %%
x=[4,5,6,7,8,9]
y=[40,80,70,60,50,90]
colour=['#008000','#FFA500','#00FFFF','#00008B','#FF0000','#FF00FF']
plt.scatter(x,y,c=colour,alpha=0.8,marker='*')
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)
fig=plt.figure()
